# %%
# Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Hotel Bookings.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.duplicated().sum() # Finding the duplicated values
# Out:
# 31994

# %%
df.drop_duplicates(inplace=True) # The duplicates are droped

# %%
df.duplicated().sum() # we can see that the duplicates are droped
# Out:
# 0

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %%
# finding the null value percentage
(df.isnull().sum()/len(df))*100
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.004577
# babies                             0.000000
# meal                               0.000000
# country                            0.517186
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %%
# From the above we can infer that there is a 93 percent null value in the company column

# %%
null_value_columns = df.columns[df.isnull().any()].tolist()

# %%
null_value_columns
# Out:
# ['children', 'country', 'agent', 'company']

# %%
# Treating the Null values

# %%
# Im dropping the null values of children column as it is a very minute percent

# %%
df.dropna(subset=['children'],inplace=True)

# %%
df['children'].isna().sum() # there are no more null values in the children column
# Out:
# 0

# %%
df['country'].isna().sum()
# Out:
# 452

# %%
df['country'].unique() # These are the unique values available in the country
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
df['country'].value_counts(ascending=False) # Im going to impute the missing values of the country with mode so the frequently occuring value here is 'PRT'
# Out:
# country
# PRT    27449
# GBR    10433
# FRA     8837
# ESP     7252
# DEU     5387
#        ...
# MMR        1
# BFA        1
# CYM        1
# MLI        1
# KHM        1
# Name: count, Length: 177, dtype: int64

# %%
df['country'] = df['country'].fillna('PRT')

# %%
df['country'].value_counts()
# Out:
# country
# PRT    27901
# GBR    10433
# FRA     8837
# ESP     7252
# DEU     5387
#        ...
# MMR        1
# BFA        1
# CYM        1
# MLI        1
# KHM        1
# Name: count, Length: 177, dtype: int64

# %%
df['country'].isna().sum() # The missing values have been imputed with mode
# Out:
# 0

# %%
null_value_columns
# Out:
# ['children', 'country', 'agent', 'company']

# %%
df['agent']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3         304.0
# 4         240.0
#           ...
# 119385    394.0
# 119386      9.0
# 119387      9.0
# 119388     89.0
# 119389      9.0
# Name: agent, Length: 87392, dtype: float64

# %%
df['agent'].dtype
# Out:
# dtype('float64')

# %%
# lets find if this column contains any outliers before imputing it

# %%
# using boxplot

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=df['agent'])
plt.title("identifying outliers")
# Out:
# Text(0.5, 1.0, 'identifying outliers')

# %%
#  Lets impute the missing values

# %%
df['agent'] = df['agent'].fillna(df['agent'].median()) # we are imputing with median as median is not influenced by outliers

# %%
df['agent']
# Out:
# 0          14.0
# 1          14.0
# 2          14.0
# 3         304.0
# 4         240.0
#           ...
# 119385    394.0
# 119386      9.0
# 119387      9.0
# 119388     89.0
# 119389      9.0
# Name: agent, Length: 87392, dtype: float64

# %%
df['agent'].isna().sum() # The agent column Nan values were imputed with median
# Out:
# 0

# %%
null_value_columns
# Out:
# ['children', 'country', 'agent', 'company']

# %%
df['company'].unique()
# Out:
# array([ nan, 110., 113., 270., 178., 240., 154., 144., 307., 268.,  59.,
#        204., 312., 318.,  94., 174., 274., 195., 223., 317., 281., 118.,
#         53., 286.,  12.,  47., 324., 342., 373., 371., 383.,  86.,  82.,
#        218.,  88.,  31., 397., 392., 405., 331., 367.,  20.,  83., 416.,
#         51., 395., 102.,  34.,  84., 360., 394., 457., 382., 461., 478.,
#        386., 112., 486., 421.,   9., 308., 135., 224., 504., 269., 356.,
#        498., 390., 513., 203., 263., 477., 521., 169., 515., 445., 337.,
#        251., 428., 292., 388., 130., 250., 355., 254., 543., 531., 528.,
#         62., 120.,  42.,  81., 116., 530., 103.,  39.,  16.,  92.,  61.,
#        501., 165., 291., 290.,  43., 325., 192., 108., 200., 465., 287.,
#        297., 490., 482., 207., 282., 437., 225., 329., 272.,  28.,  77.,
#        338.,  72., 246., 319., 146., 159., 380., 323., 511., 407., 278.,
#         80., 403., 399.,  14., 137., 343., 346., 347., 349., 289., 351.,
# ...

# %%
sns.boxplot(x=df['company'])
# Out:
# <Axes: xlabel='company'>

# %%
df['company'] = df['company'].fillna(df['company'].median())

# %%
df['company']
# Out:
# 0         169.0
# 1         169.0
# 2         169.0
# 3         169.0
# 4         169.0
#           ...
# 119385    169.0
# 119386    169.0
# 119387    169.0
# 119388    169.0
# 119389    169.0
# Name: company, Length: 87392, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.histplot(x=df['company'],kde=True,color='crimson',edgecolor='black')
plt.title('distribution of the data after imputating with median')
plt.show()

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
df.columns[df.isnull().any()] # As we can see that all the missing values are imputed
# Out:
# Index([], dtype='object')

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# Gathering insights
# Lets split the columns into numerical and categorical ones

# %%
numerical_cols = df.select_dtypes(include=['int','float'])
categorical_cols = df.select_dtypes(include=['object'])

# %%
categorical_cols
# Out:
#                hotel arrival_date_month meal country market_segment  \
# 0       Resort Hotel               July   BB     PRT         Direct
# 1       Resort Hotel               July   BB     PRT         Direct
# 2       Resort Hotel               July   BB     GBR         Direct
# 3       Resort Hotel               July   BB     GBR      Corporate
# 4       Resort Hotel               July   BB     GBR      Online TA
# ...              ...                ...  ...     ...            ...
# 119385    City Hotel             August   BB     BEL  Offline TA/TO
# 119386    City Hotel             August   BB     FRA      Online TA
# 119387    City Hotel             August   BB     DEU      Online TA
# 119388    City Hotel             August   BB     GBR      Online TA
# 119389    City Hotel             August   HB     DEU      Online TA
#
#        distribution_channel reserved_room_type assigned_room_type  \
# 0                    Direct                  C                  C
# ...

# %%
numerical_cols
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
# Categorical Data Analysis

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='hotel',data=df,palette='viridis',edgecolor='black')
plt.title("Distribution of types of hotel")
plt.show()
# Out:
# C:\Users\Saji R\AppData\Local\Temp\ipykernel_17248\1183124131.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='hotel',data=df,palette='viridis',edgecolor='black')

# %%
# Insights--> I can say that the city hotels are more in number than Resort hotel it means more people opt for short term business based stays

# %%
df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
#BB-> BED and breakfast accomodation and breakfast
#hb half board breakfast dinner
# fb full board- breafast lunch  dinner
# sc self catering

# %%
plt.figure(figsize=(8,6))
plt.title("The type of Stay with respect to meals")
sns.countplot(x='meal',data=df,palette='pastel',edgecolor='black')
plt.show()
# Out:
# C:\Users\Saji R\AppData\Local\Temp\ipykernel_17248\631347786.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='meal',data=df,palette='pastel',edgecolor='black')

# %%
# Insights--> most of the people perfer to accomodation and Breakfast

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='arrival_date_month',data=df,palette='coolwarm',edgecolor='black')
plt.xticks(rotation=90)
plt.xlabel("Arrival by Month")
plt.show()
# Out:
# C:\Users\Saji R\AppData\Local\Temp\ipykernel_17248\1317168109.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='arrival_date_month',data=df,palette='coolwarm',edgecolor='black')

# %%
# Insight--> we can see that most people have arrived during the month of august so that month must have had peak business

# %%
df['reserved_room_type'].unique()
# Out:
# array(['C', 'A', 'D', 'E', 'G', 'F', 'H', 'L', 'P', 'B'], dtype=object)

# %%
# A: Standard Single Room
# B: Standard Double Room
# C: Standard Twin Room
# D: Deluxe Double Room
# E: Studio Room or Apartment
# F: Junior Suite
# G: Executive Suite
# H: Presidential Suite

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='reserved_room_type',data=df,palette='pastel',edgecolor='black')
t = pd.crosstab(df['reserved_room_type'],df['hotel'])
t.plot(kind='bar',stacked=False,figsize=(10,8))
plt.show
# Out:
# C:\Users\Saji R\AppData\Local\Temp\ipykernel_17248\3365306903.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='reserved_room_type',data=df,palette='pastel',edgecolor='black')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# insights--> Here i can say that most of the customer prefer standard single room we can say that most of the people that stay here are not with family

# %%
df['customer_type'].unique()
# Out:
# array(['Transient', 'Contract', 'Transient-Party', 'Group'], dtype=object)

# %%
#"Transient" refers to individual or small group bookings, often for short stays, while "Contract" signifies a long-term agreement for a block of rooms, "Transient-Party" indicates a transient booking associated with other transient bookings, and "Group" represents bookings for multiple rooms by a large entity.

# %%
x = pd.crosstab(index=df['customer_type'],columns=df['hotel'])

# %%
x
# Out:
# hotel            City Hotel  Resort Hotel
# customer_type
# Contract               1471          1668
# Group                   271           273
# Transient             44641         27345
# Transient-Party        7041          4682

# %%
x.plot(kind='pie',subplots=True,figsize=(14,14),autopct='%1.1f%%',startangle=140,colormap='coolwarm')
plt.title("The type of stays booked")
plt.xlabel("Customer type")
plt.tight_layout()
plt.show()

# %%
# Insights--> The insights here are that most people book rooms here for short stay in both resort type and city type hotel

# %%
df['reservation_status'].unique()
df['reservation_status'].value_counts()
# Out:
# reservation_status
# Check-Out    63371
# Canceled     23007
# No-Show       1014
# Name: count, dtype: int64

# %%
pd.crosstab(df['customer_type'],df['reservation_status'])
# Out:
# reservation_status  Canceled  Check-Out  No-Show
# customer_type
# Contract                 487       2627       25
# Group                     50        490        4
# Transient              20808      50314      864
# Transient-Party         1662       9940      121

# %%
df['reserved_room_type']
# Out:
# 0         C
# 1         C
# 2         A
# 3         A
# 4         A
#          ..
# 119385    A
# 119386    E
# 119387    D
# 119388    A
# 119389    A
# Name: reserved_room_type, Length: 87392, dtype: object

# %%
df['assigned_room_type']
# Out:
# 0         C
# 1         C
# 2         C
# 3         A
# 4         A
#          ..
# 119385    A
# 119386    E
# 119387    D
# 119388    A
# 119389    A
# Name: assigned_room_type, Length: 87392, dtype: object

# %%
df['reserved_room_type']
# Out:
# 0         C
# 1         C
# 2         A
# 3         A
# 4         A
#          ..
# 119385    A
# 119386    E
# 119387    D
# 119388    A
# 119389    A
# Name: reserved_room_type, Length: 87392, dtype: object

# %%
x = pd.crosstab(df['assigned_room_type'],df['reserved_room_type'],normalize='index')*100

# %%
x.plot(kind="bar", stacked=True, figsize=(12,6), colormap="coolwarm",edgecolor='black')
plt.xlabel("Reserved Room type")
plt.ylabel("percentage")
plt.title("Comparison between reserved room and assigned room")
# Out:
# Text(0.5, 1.0, 'Comparison between reserved room and assigned room')

# %%
df.groupby(['reserved_room_type','assigned_room_type'])['is_canceled'].size().reset_index()
# Out:
#    reserved_room_type assigned_room_type  is_canceled
# 0                   A                  A        45879
# 1                   A                  B          894
# 2                   A                  C         1256
# 3                   A                  D         6410
# 4                   A                  E         1035
# ..                ...                ...          ...
# 70                  L                  C            1
# 71                  L                  F            1
# 72                  L                  H            1
# 73                  L                  L            1
# 74                  P                  P            6
#
# [75 rows x 3 columns]

# %%
#--> Insights i can say that most of the reserved rooms are different and the assigned rooms are different this mid lead disatisfaction for the customer 
# it will impact the business negatively
# it is better to provide the customer what they ask
# There are more number of cancellations because of this factor

# %%
categorical_cols
# Out:
#                hotel arrival_date_month meal country market_segment  \
# 0       Resort Hotel               July   BB     PRT         Direct
# 1       Resort Hotel               July   BB     PRT         Direct
# 2       Resort Hotel               July   BB     GBR         Direct
# 3       Resort Hotel               July   BB     GBR      Corporate
# 4       Resort Hotel               July   BB     GBR      Online TA
# ...              ...                ...  ...     ...            ...
# 119385    City Hotel             August   BB     BEL  Offline TA/TO
# 119386    City Hotel             August   BB     FRA      Online TA
# 119387    City Hotel             August   BB     DEU      Online TA
# 119388    City Hotel             August   BB     GBR      Online TA
# 119389    City Hotel             August   HB     DEU      Online TA
#
#        distribution_channel reserved_room_type assigned_room_type  \
# 0                    Direct                  C                  C
# ...

# %%
df['deposit_type'].unique()
# Out:
# array(['No Deposit', 'Refundable', 'Non Refund'], dtype=object)

# %%
d = pd.crosstab(df['deposit_type'],df['reservation_status'])

# %%
d
# Out:
# reservation_status  Canceled  Check-Out  No-Show
# deposit_type
# No Deposit             22005      63235     1007
# Non Refund               977         55        6
# Refundable                25         81        1

# %%
d.plot(kind='bar',figsize=(10,10),colormap='viridis')
plt.title("Comparison on how deposits influence the resevation status")
plt.xlabel("Deposit type")
plt.xticks(rotation=0)
plt.ylabel("count")
plt.show()

# %%
# INSIGHTS

# PROBLEMS
# we can say that people without deposit are either cancelling their reservation or giving a no show 
# It is because of them most of them are not able to reserve rooms properly and are allocated different rooms

# SOLUTION
# collect atleast a minimum amount of deposit from the customers
# Check their previous records whether he/she is a good customer

# %%
df['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Aviation'], dtype=object)

# %%
#"Direct" (guests booking directly with the hotel), "Corporate" (business travelers), "Online TA" (online travel agencies), "Offline TA/TO" (offline travel agents/tour operators), "Complementary" (guests booked through complementary channels), "Groups" (large groups), and "Aviation" (travelers related to airlines

# %%
df.groupby(["market_segment", "reservation_status"]).size().reset_index(name="count")
# Out:
#    market_segment reservation_status  count
# 0        Aviation           Canceled     34
# 1        Aviation          Check-Out    182
# 2        Aviation            No-Show     11
# 3   Complementary           Canceled     77
# 4   Complementary          Check-Out    614
# 5   Complementary            No-Show     11
# 6       Corporate           Canceled    441
# 7       Corporate          Check-Out   3702
# 8       Corporate            No-Show     69
# 9          Direct           Canceled   1556
# 10         Direct          Check-Out  10067
# 11         Direct            No-Show    180
# 12         Groups           Canceled   1299
# 13         Groups          Check-Out   3607
# 14         Groups            No-Show     36
# 15  Offline TA/TO           Canceled   1888
# 16  Offline TA/TO          Check-Out  11826
# 17  Offline TA/TO            No-Show    175
# 18      Online TA           Canceled  17712
# 19      Online TA          Check-Out  33373
# ...

# %%
# Insights-> 
# Here more number  of cancellations and no show has happened in Online TA market segment
# The possible reasons behind that could be not providing compelling discounts 
# No proper customer support
# The condition of the rooms may be bad 
# The other customers may post bad reviews which may damage the reputation and the trust of the customers who are booking online


# SOLUTION

# keeping the rooms neat and clean
# Providing some additional discount or coupons
# Proper maintainence of the amenities
# Providing good customer support
# Providing some adds showcasing the quality

# %%
# Numerical Data

# %%
numerical_cols
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
sns.countplot(x='arrival_date_year',data=df,palette='pastel')
# Out:
# C:\Users\Saji R\AppData\Local\Temp\ipykernel_17248\3557674784.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='arrival_date_year',data=df,palette='pastel')
# <Axes: xlabel='arrival_date_year', ylabel='count'>

# %%
# Insights-->
# In the year 2016 more customers have arrived to the hotel

# %%
numerical_cols.columns
# Out:
# Index(['is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_week_number', 'arrival_date_day_of_month',
#        'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
#        'babies', 'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company',
#        'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests'],
#       dtype='object')

# %%
numerical_cols
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
# the time between a guest making their booking and arriving at your hotel for their stay.31 Jul 2024

df['lead_time'].value_counts()
# Out:
# lead_time
# 0      5978
# 1      3214
# 2      1926
# 3      1704
# 4      1570
#        ...
# 410       1
# 411       1
# 371       1
# 532       1
# 463       1
# Name: count, Length: 479, dtype: int64

# %%
sns.histplot(df['lead_time'])
# Out:
# <Axes: xlabel='lead_time', ylabel='Count'>

# %%
# Insights-->

# PROBLEM
# we can se a gradual decrease in the lead time this means people are not advance booking the hotel
# It can also mean the no of customers coming to the hotel has reduced so the booking can be done at any time
# The demand has reduced

# Solution

# What we can do the discount can be increased to give people within a time frame so they can book

# %%
plt.figure(figsize=(14,14))
sns.countplot(x='arrival_date_day_of_month',data=df,palette='pastel',edgecolor='black')
plt.xlabel("Arrival Date")
plt.show()
# Out:
# C:\Users\Saji R\AppData\Local\Temp\ipykernel_17248\3003990963.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='arrival_date_day_of_month',data=df,palette='pastel',edgecolor='black')

# %%
# Insights-->
# The customers are more likely to come in between the months

# %%
df['arrival_date_month'].value_counts()
# Out:
# arrival_date_month
# August       11253
# July         10057
# May           8355
# April         7908
# June          7765
# March         7513
# October       6934
# September     6690
# February      6098
# December      5131
# November      4995
# January       4693
# Name: count, dtype: int64

# %%
categorical_cols
# Out:
#                hotel arrival_date_month meal country market_segment  \
# 0       Resort Hotel               July   BB     PRT         Direct
# 1       Resort Hotel               July   BB     PRT         Direct
# 2       Resort Hotel               July   BB     GBR         Direct
# 3       Resort Hotel               July   BB     GBR      Corporate
# 4       Resort Hotel               July   BB     GBR      Online TA
# ...              ...                ...  ...     ...            ...
# 119385    City Hotel             August   BB     BEL  Offline TA/TO
# 119386    City Hotel             August   BB     FRA      Online TA
# 119387    City Hotel             August   BB     DEU      Online TA
# 119388    City Hotel             August   BB     GBR      Online TA
# 119389    City Hotel             August   HB     DEU      Online TA
#
#        distribution_channel reserved_room_type assigned_room_type  \
# 0                    Direct                  C                  C
# ...

# %%
numerical_cols
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
df['reservation_status_date']
# Out:
# 0         2015-07-01
# 1         2015-07-01
# 2         2015-07-02
# 3         2015-07-02
# 4         2015-07-03
#              ...
# 119385    2017-09-06
# 119386    2017-09-07
# 119387    2017-09-07
# 119388    2017-09-07
# 119389    2017-09-07
# Name: reservation_status_date, Length: 87392, dtype: object

# %%
df['reservation_dates'] = pd.to_datetime(df['reservation_status_date'])

# %%
df['reservation_dates']
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_dates, Length: 87392, dtype: datetime64[ns]

# %%
df['reservation_year'] = df['reservation_dates'].dt.year

# %%
df['reservation_day']  = pd.to_datetime(df['reservation_dates']).dt.day

# %%
df['reservation_month'] = pd.to_datetime(df['reservation_dates']).dt.month

# %%
df['reservation_year']
# Out:
# 0         2015
# 1         2015
# 2         2015
# 3         2015
# 4         2015
#           ...
# 119385    2017
# 119386    2017
# 119387    2017
# 119388    2017
# 119389    2017
# Name: reservation_year, Length: 87392, dtype: int32

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='reservation_year',data=df,palette='coolwarm',edgecolor='black')
# Out:
# C:\Users\Saji R\AppData\Local\Temp\ipykernel_17248\1246853737.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='reservation_year',data=df,palette='coolwarm',edgecolor='black')
# <Axes: xlabel='reservation_year', ylabel='count'>

# %%
# Insights --> # More number of reservations have happened on the year 2016
# The year 2016 was the year when more numbers of reservations were made
# Problems --> The corresponding year has seen a decline 
# Possible Reasons--> The customers were dissatisfied about the hotel services 
# Not getting the desired rooms
# Not enough discounts provided
# No proper maintainence

# %%
x = df.groupby('reservation_month')['lead_time'].mean()

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=df['reservation_month'], y=df['lead_time'],palette='pastel',edgecolor='black')
plt.title("The lead time for different reservation months")
plt.ylabel('Lead Time')
plt.xlabel('Reservation months')
plt.show()
# Out:
# C:\Users\Saji R\AppData\Local\Temp\ipykernel_17248\607719314.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['reservation_month'], y=df['lead_time'],palette='pastel',edgecolor='black')

# %%
# Insights-->

# The lead time for the months like months like may june july august september and october are high 
# This means that customers perfer to come during that month

# we need to ensure that at time the hotel performs at its best
# we need to utilize the human resources properly and provide the customers better service so we dont lose them the next time
# That time can be the peak time to make profit
# To increase the business profit maybe we can provide discounts so that more customers will be attracted

# %%
grouped = df.groupby('reservation_day')['is_canceled'].sum().reset_index()

# %%
grouped
# Out:
#     reservation_day  is_canceled
# 0                 1          728
# 1                 2          844
# 2                 3          789
# 3                 4          830
# 4                 5          785
# 5                 6          842
# 6                 7          817
# 7                 8          747
# 8                 9          854
# 9                10          794
# 10               11          748
# 11               12          799
# 12               13          800
# 13               14          752
# 14               15          794
# 15               16          773
# 16               17          792
# 17               18          781
# 18               19          785
# 19               20          801
# 20               21          934
# 21               22          867
# 22               23          793
# 23               24          755
# 24               25          778
# 25               26          704
# 26               27          737
# ...

# %%
plt.plot(grouped['reservation_day'], grouped['is_canceled'], marker='o', linestyle='-')
plt.ylabel('Cancelation count')
plt.title("Cancelation per day")
plt.xlabel("Reservation Days")
plt.show()

# %%
# Insights-->

# Problem

# The cancelation is very high during the inital days and the  middle of the month

#Solution
# may be we this can be due to non availability of the preffered room type
# we can reduce the cost if possible and provide discounts for the customer

# %%
numerical_cols
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
z = df.groupby(['stays_in_week_nights'])['is_canceled'].sum().reset_index()

# %%
z
# Out:
#     stays_in_week_nights  is_canceled
# 0                      0         1145
# 1                      1         4938
# 2                      2         5965
# 3                      3         4856
# 4                      4         2557
# 5                      5         3022
# 6                      6          520
# 7                      7          296
# 8                      8          199
# 9                      9           84
# 10                    10          260
# 11                    11           29
# 12                    12           22
# 13                    13           11
# 14                    14           21
# 15                    15           29
# 16                    16            8
# 17                    17            2
# 18                    18            5
# 19                    19           13
# 20                    20           17
# 21                    21           11
# 22                    22            7
# 23                    24            2
# ...

# %%
plt.plot(z['stays_in_week_nights'], z['is_canceled'], marker='o', linestyle='-',color='red')
plt.ylabel('Cancelation count')
plt.title("Stays week nights vs Cancelation count")
plt.xlabel("Stay in week nights")
plt.show()

# %%
# Insights--> Initially the customers cancel after staying for 2 to 3 days and then  the cancelation slow comes down as the days progress

# Problem

# The high cancelation during initial days

# Solution 
# The cancelation may be due to some accomodation issues like the room quality we can identify these areas and rectify this

# %%
categorical_cols
# Out:
#                hotel arrival_date_month meal country market_segment  \
# 0       Resort Hotel               July   BB     PRT         Direct
# 1       Resort Hotel               July   BB     PRT         Direct
# 2       Resort Hotel               July   BB     GBR         Direct
# 3       Resort Hotel               July   BB     GBR      Corporate
# 4       Resort Hotel               July   BB     GBR      Online TA
# ...              ...                ...  ...     ...            ...
# 119385    City Hotel             August   BB     BEL  Offline TA/TO
# 119386    City Hotel             August   BB     FRA      Online TA
# 119387    City Hotel             August   BB     DEU      Online TA
# 119388    City Hotel             August   BB     GBR      Online TA
# 119389    City Hotel             August   HB     DEU      Online TA
#
#        distribution_channel reserved_room_type assigned_room_type  \
# 0                    Direct                  C                  C
# ...

# %%
grouped = df.groupby('customer_type')['is_canceled'].sum().reset_index()

# %%
plt.figure(figsize=(10,8))
plt.bar(grouped['customer_type'],grouped['is_canceled'],color='gray')
plt.title("Cancellations made by different type of customers")
plt.xlabel("Types of customer")
plt.ylabel("count")
plt.legend()
plt.show()
# Out:
# C:\Users\Saji R\AppData\Local\Temp\ipykernel_17248\3807428488.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Insights -->

# The type of customer with more cancelations are the transient type
# They are the guys for short stay
# The possible reasons for cancellation may be they got another cheap one than this hotel
# Maybe they dont like the food quailty 

# Solution 
# we can proritize the transient customers we can offer more discounts for this particular group
# Also we can improve the food quality

# %%
grouped = df.groupby('market_segment')['is_canceled'].sum().reset_index()

# %%
plt.figure(figsize=(10,8))
plt.bar(grouped['market_segment'],grouped['is_canceled'],color='skyblue')
plt.title("Cancelation on the market segment")
plt.xticks(rotation=90)
plt.xlabel("Market segment")
plt.ylabel("cancellation count")
plt.show()

# %%
# Insights-->
# More cancelation happen in online TA
# we need to provide more customer support and more offers

# %%
numerical_cols
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
df['adr']
# Out:
# 0           0.00
# 1           0.00
# 2          75.00
# 3          75.00
# 4          98.00
#            ...
# 119385     96.14
# 119386    225.43
# 119387    157.71
# 119388    104.40
# 119389    151.20
# Name: adr, Length: 87392, dtype: float64

# %%
grouped = df.groupby('arrival_date_day_of_month')['adr'].mean().reset_index()

# %%
grouped
# Out:
#     arrival_date_day_of_month         adr
# 0                           1  107.852329
# 1                           2  102.052636
# 2                           3  104.062527
# 3                           4  102.615505
# 4                           5  101.339335
# 5                           6  105.197971
# 6                           7  109.087851
# 7                           8  106.964813
# 8                           9  103.699965
# 9                          10  107.367174
# 10                         11  105.558223
# 11                         12  102.497375
# 12                         13  109.400263
# 13                         14  105.630345
# 14                         15  109.204754
# 15                         16  105.737029
# 16                         17  108.767603
# 17                         18  105.228608
# 18                         19  105.002377
# 19                         20  106.381026
# 20                         21  106.683776
# ...

# %%
plt.figure(figsize=(10,8))
plt.plot(grouped['arrival_date_day_of_month'],grouped['adr'],marker="o",linestyle='-',color='cyan')
plt.title("Average Daily revenue with respect to the days")
plt.xlabel("days")
plt.ylabel("adr")
plt.plot()
# Out:
# []

# %%
# Insights

# Here we can see the revenue it is at the peak in the middle of month

# %%
numerical_cols
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
df.groupby('customer_type')['required_car_parking_spaces'].count()
# Out:
# customer_type
# Contract            3139
# Group                544
# Transient          71986
# Transient-Party    11723
# Name: required_car_parking_spaces, dtype: int64

# %%
df['reservation_year']
# Out:
# 0         2015
# 1         2015
# 2         2015
# 3         2015
# 4         2015
#           ...
# 119385    2017
# 119386    2017
# 119387    2017
# 119388    2017
# 119389    2017
# Name: reservation_year, Length: 87392, dtype: int32

# %%
df['arrival_date_year'] = df['arrival_date_year'].astype(int)

# %%
df['arrival_date_year'].dtype
# Out:
# dtype('int32')

# %%
df_2016 = df[df['arrival_date_year']==2016]

# %%
df_2016
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 3738    Resort Hotel            0        109               2016
# 3739    Resort Hotel            0        109               2016
# 3740    Resort Hotel            1          2               2016
# 3741    Resort Hotel            0         88               2016
# 3742    Resort Hotel            1         20               2016
# ...              ...          ...        ...                ...
# 104139    City Hotel            0        173               2016
# 104142    City Hotel            0         17               2016
# 104145    City Hotel            0        177               2016
# 104147    City Hotel            0        107               2016
# 104216    City Hotel            0        310               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 3738              January                         1
# 3739              January                         1
# ...

# %%
yearly_cancellation = df.groupby('arrival_date_year')['is_canceled'].sum()

# %%
yearly_cancellation
# Out:
# arrival_date_year
# 2015     2700
# 2016    11208
# 2017    10113
# Name: is_canceled, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.bar(yearly_cancellation.index,yearly_cancellation.values)

plt.xticks(ticks=yearly_cancellation.index, labels=yearly_cancellation.index.astype(int))
plt.xlabel('arrival years')
plt.title('Cancellation per year')
plt.show()

# %%
# Insights--> The cancellation has decreased a bit in 2017

# %%
grouped = df.groupby('arrival_date_year')['adr'].mean()

# %%
plt.figure(figsize=(10,8))
plt.title("Adr rate change over the years")
plt.xlabel("Years")
plt.ylabel("adr rate")
plt.plot(grouped.index,grouped.values,marker="o",linestyle='-',color='red')
plt.xticks(ticks=grouped.index, labels=grouped.index.astype(int))
plt.show()

# %%
# Insights-->
# The adr rate has increaed over the years
# This means the hotel is making good revenue

# %%
grouped = df.groupby(['customer_type','arrival_date_year'])['is_canceled'].sum().reset_index()

# %%
sns.barplot(y='is_canceled',x='arrival_date_year',hue='customer_type',data=grouped)
# Out:
# <Axes: xlabel='arrival_date_year', ylabel='is_canceled'>

# %%
# Insights-->
# As we can see over time the cancellations have reduced
# So the profit of hotel should ve increased

# %%
numerical_cols
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
grouped = df.groupby(['customer_type','arrival_date_year'])['is_repeated_guest'].count().reset_index()

# %%
grouped
# Out:
#       customer_type  arrival_date_year  is_repeated_guest
# 0          Contract               2015               1831
# 1          Contract               2016                683
# 2          Contract               2017                625
# 3             Group               2015                180
# 4             Group               2016                151
# 5             Group               2017                213
# 6         Transient               2015               8656
# 7         Transient               2016              35656
# 8         Transient               2017              27674
# 9   Transient-Party               2015               2642
# 10  Transient-Party               2016               5901
# 11  Transient-Party               2017               3180

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='customer_type',y='is_repeated_guest',hue='arrival_date_year',data=grouped)
# Out:
# <Axes: xlabel='customer_type', ylabel='is_repeated_guest'>

# %%
# Insights -->we can see that transient peole have been repeatedly visiting

# %%
# Conclusion:

# The hotel has been making profits over the years

# %%
grouped = df.groupby(['arrival_date_year','market_segment'])['reservation_status'].count().reset_index()

# %%
plt.figure(figsize=(10,8))
plt.title("Reservation status over time")
sns.lineplot(x='market_segment',y='reservation_status',hue='arrival_date_year',data=grouped,palette='coolwarm')
# Out:
# <Axes: title={'center': 'Reservation status over time'}, xlabel='market_segment', ylabel='reservation_status'>

# %%
# insights -->
# The graph follows the same trend but 2017 has seen a decline 
# The reservation have gone low

# %%
room_mismatch = df[df['reserved_room_type'] != df['assigned_room_type']]
room_mismatch

room_mismatch_count = room_mismatch.groupby('arrival_date_year')['reserved_room_type'].count()

# %%
room_mismatch_count
# Out:
# arrival_date_year
# 2015    3015
# 2016    6918
# 2017    3176
# Name: reserved_room_type, dtype: int64

# %%
# We can say that the room mismatches have also reduced
